# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
import os 
os.getcwd()
# Out:
# 'c:\\Users\\hamoud\\Desktop\\Fraud_detection'

# %%
train_data = pd.read_csv("creditcard_train_scaled.csv")
test_data = pd.read_csv("creditcard_test_scaled.csv")
train_data
# Out:
#               V1        V2        V3        V4        V5        V6        V7  \
# 0      -0.917597  1.468375  1.607758 -0.021990 -0.283089 -1.229240  0.753631
# 1      -0.699142  0.319290  2.278452  0.736121 -0.684040  0.742862  0.375170
# 2      -0.571369  1.317794  1.019639  1.021975 -0.042067 -0.127407  0.277220
# 3       1.147507 -1.921087 -0.261885  1.487177 -0.829881  1.908747 -0.955687
# 4      -0.629345  0.848104  1.146756  0.566688  0.934798  0.073785  0.859693
# ...          ...       ...       ...       ...       ...       ...       ...
# 227840  0.095639  0.101785  1.261669 -1.375506 -0.519103 -0.233864 -0.100928
# 227841 -6.046362 -1.285178 -2.486027  0.271327 -3.502477  0.974063  0.025943
# 227842  0.033797  0.882025  0.306073 -0.583187  0.450910 -1.128918  1.033273
# 227843 -2.011805  0.510858  0.773423 -1.790730  0.866647  0.349700  0.598281
# 227844 -1.959402  1.997522  0.345605 -0.305297 -0.642357 -0.538113 -0.135870
#
#               V8        V9       V10  ...       V22       V23       V24  \
# 0      -0.146383 -0.231226  0.272734  ... -0.441894  0.050339  0.924543
# 1       0.367698 -0.234212 -0.523238  ...  0.993618  0.085713  0.224880
# 2       0.433044 -1.207277 -0.179688  ...  0.703393 -0.196171  0.041482
# 3       0.517632  1.752487 -0.071405  ...  0.604139 -0.294560 -0.384808
# 4      -0.066140 -0.817268 -0.399711  ...  0.023712 -0.422906 -0.992322
# ...          ...       ...       ...  ...       ...       ...       ...
# 227840 -0.147033 -1.281357  0.323678  ...  0.105428 -0.029562 -0.351602
# 227841  2.182822  0.245799 -1.772681  ... -0.193982  0.159401 -0.541897
# 227842 -0.231043 -0.107794 -0.422426  ... -0.536077  0.069324  0.050828
# 227843 -0.007178  0.760874  0.809981  ... -0.180485  0.168770 -1.270998
# 227844  0.942992 -0.329781  0.440685  ... -0.633464  0.066853 -0.027007
#
#              V25       V26       V27       V28  scaled_amount  scaled_time  \
# 0      -0.120948  0.043518  0.484835  0.256764      -0.289650    -0.369625
# 1      -0.032720 -0.288623  0.090848  0.074140       1.510490    -0.290133
# 2      -0.135509 -0.215535  0.043891  0.080868      -0.128951    -0.350920
# 3      -0.231287 -0.544888  0.037585  0.036367       5.265734     0.394304
# 4       0.739840 -0.111136  0.050766  0.068694       0.348951    -0.571407
# ...          ...       ...       ...       ...            ...          ...
# 227840 -0.957453  1.370403  0.143042  0.177850      -0.096503     0.013436
# 227841 -0.645865  0.715113  0.107730 -1.271921       4.024615    -0.047256
# 227842 -0.475434  0.136317  0.249307  0.098713      -0.257483     0.837261
# 227843 -0.036114  0.810049  0.351317  0.070897       0.111888    -0.347517
# 227844  0.011540  0.079430  0.198059  0.157961      -0.181958    -0.452603
#
#         Class
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 227840      0
# 227841      0
# 227842      0
# 227843      0
# 227844      0
#
# [227845 rows x 31 columns]

# %%
X_train = train_data.drop(columns="Class")
y_train = train_data["Class"]
print(X_train.shape,y_train.shape)
# Out:
# (227845, 30) (227845,)

# %%
X_test = test_data.drop(columns="Class")
y_test = test_data["Class"]
print(X_test.shape,y_test.shape)
# Out:
# (56962, 30) (56962,)
